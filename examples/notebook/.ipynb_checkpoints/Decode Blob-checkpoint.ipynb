# %%
import psycopg2
import os
import base64

# %%
try:
    connection = psycopg2.connect(user="postgres",
                                  password="start.123",
                                  host="postgres",
                                  port="5432",
                                  database="documents")
    cursor = connection.cursor()
    postgreSQL_select_Query = "select filename, encode(blob, 'base64') FROM document_informations;"

    cursor.execute(postgreSQL_select_Query)
    print("Selecting rows from mobile table using cursor.fetchall")
    mobile_records = cursor.fetchall()

    print("Print each row and it's columns values")
    for row in mobile_records:
        print("filename = ", row[0], )
        print("blob = ", row[1])
#        print("extension  = ", row[2], "\n")

except (Exception, psycopg2.Error) as error:
    print("Error while fetching data from PostgreSQL", error)

finally:
    # closing database connection.
    if connection:
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Error while fetching data from PostgreSQL could not translate host name "postgres" to address: Unknown host
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-da366dfd884a> in <module>
#      23 finally:
#      24     # closing database connection.
# ---> 25     if connection:
#      26         cursor.close()
#      27         connection.close()
#
# NameError: name 'connection' is not defined

# %%
connection = psycopg2.connect(
                              host="localhost",
     port="5432",
                              database="documents",
                              user="postgres",
                              password="start.123")
cursor = connection.cursor()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-30-eb52be889094> in <module>
#       4                               database="documents",
#       5                               user="postgres",
# ----> 6                               password="start.123")
#       7 cursor = connection.cursor()
#
# ~\AppData\Local\Programs\Python\Python37\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError:

# %%
t = mobile_records[0][1]
t = str.encode(t)

# %%
base64_message = t.decode()

# %%
base64_message
# Out:
# '\nZEEzTklSU3hGQ3RtU1FKM ...

# %%
t = mobile_records[0][1]
e = base64.b64decode(t)

# %%
with open(os.path.expanduser('t.pdf'), 'wb') as fout:
    fout.write(base64.decodestring(e))

# %%
dict(mobile_records)
# Out:
# {'musterrechnung-kleinunternehmerregelung.pdf': '\nd2Y5eWlvQ3Bpazl0dkd0OFp3dVFsTWh0Y3JHS3lMeGM5VmpyMEx ...

# %%
for k,v in dict(mobile_records).items():
    print(k)
# Out:
# musterrechnung-kleinunternehmerregelung.pdf
